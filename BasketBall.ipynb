# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression

# %%
data=pd.read_csv('basketball.csv')

# %%
data.head()
# Out:
#    Height  Weight  SuccessGoals  SuccessThrows  PointsScored
# 0     6.8     225         0.442          0.672           9.2
# 1     6.3     180         0.435          0.797          11.7
# 2     6.4     190         0.456          0.761          15.8
# 3     6.2     180         0.416          0.651           8.6
# 4     6.9     205         0.449          0.900          23.2

# %%
data.head('Height')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 data.head('Height')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:5547, in NDFrame.head(self, n)
#    5474 @final
#    5475 def head(self: NDFrameT, n: int = 5) -> NDFrameT:
#    5476     """
#    5477     Return the first `n` rows.
#    5478
#    (...)
#    5545     5     parrot
#    5546     """
# -> 5547     return self.iloc[:n]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1073, in _LocationIndexer.__getitem__(self, key)
#    1070 axis = self.axis or 0
#    1072 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1602, in _iLocIndexer._getitem_axis(self, key, axis)
#    1596     raise IndexError(
#    1597         "DataFrame indexer is not allowed for .iloc\n"
#    1598         "Consider using .loc for automatic alignment."
#    1599     )
#    1601 if isinstance(key, slice):
# -> 1602     return self._get_slice_axis(key, axis=axis)
#    1604 if is_iterator(key):
#    1605     key = list(key)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1637, in _iLocIndexer._get_slice_axis(self, slice_obj, axis)
#    1634     return obj.copy(deep=False)
#    1636 labels = obj._get_axis(axis)
# -> 1637 labels._validate_positional_slice(slice_obj)
#    1638 return self.obj._slice(slice_obj, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:4212, in Index._validate_positional_slice(self, key)
#    4207 """
#    4208 For positional indexing, a slice must have either int or None
#    4209 for each of start, stop, and step.
#    4210 """
#    4211 self._validate_indexer("positional", key.start, "iloc")
# -> 4212 self._validate_indexer("positional", key.stop, "iloc")
#    4213 self._validate_indexer("positional", key.step, "iloc")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6591, in Index._validate_indexer(self, form, key, kind)
#    6588 assert kind in ["getitem", "iloc"]
#    6590 if key is not None and not is_integer(key):
# -> 6591     raise self._invalid_indexer(form, key)
#
# TypeError: cannot do positional indexing on RangeIndex with these indexers [Height] of type str

# %%
data[:,[1:2]]
# Out:
#   Cell In[65], line 1
#     data[:,[1:2]]
#              ^
# SyntaxError: invalid syntax

# %%
data["Height"].describe()
# Out:
# count    54.000000
# mean      6.587037
# std       0.458894
# min       5.700000
# 25%       6.225000
# 50%       6.650000
# 75%       6.900000
# max       7.600000
# Name: Height, dtype: float64

# %%
ranges=data['Height'].value_counts()

# %%
ranges
# Out:
# 6.8    9
# 6.4    6
# 6.9    5
# 6.1    4
# 6.3    4
# 6.2    3
# 7.0    3
# 7.3    3
# 6.0    2
# 5.9    2
# 5.8    2
# 7.1    2
# 6.5    2
# 6.7    2
# 6.6    1
# 7.2    1
# 7.6    1
# 5.7    1
# 7.4    1
# Name: Height, dtype: int64

# %%
f=plt.figure()
ranges.plot.pie(autopct='%1.0f%%')
# Out:
# <Axes: ylabel='Height'>

# %%
y=data.iloc[:,4]

# %%
y
# Out:
# 0      9.2
# 1     11.7
# 2     15.8
# 3      8.6
# 4     23.2
# 5     27.4
# 6      9.3
# 7     16.0
# 8      4.7
# 9     12.5
# 10    20.1
# 11     9.1
# 12     8.1
# 13     8.6
# 14    20.3
# 15    25.0
# 16    19.2
# 17     3.3
# 18    11.2
# 19    10.5
# 20    10.1
# 21     7.2
# 22    13.6
# 23     9.0
# 24    24.6
# 25    12.6
# 26     5.6
# 27     8.7
# 28     7.7
# 29    24.1
# 30    11.7
# 31     7.7
# 32     9.6
# 33     7.2
# 34    12.3
# 35     8.9
# 36    13.6
# 37    11.2
# 38     2.8
# 39     3.2
# 40     9.4
# 41    11.9
# 42    15.4
# 43     7.4
# 44    18.9
# 45     7.9
# 46    12.2
# 47    11.0
# 48     2.8
# 49    11.8
# 50    17.1
# 51    11.6
# 52     5.8
# 53     8.3
# Name: PointsScored, dtype: float64

# %%
x1=data.iloc[:,1:3]

# %%
x1
# Out:
#          1             2
# 0   Weight  SuccessGoals
# 1      225         0.442
# 2      180         0.435
# 3      190         0.456
# 4      180         0.416
# 5      205         0.449
# 6      225         0.431
# 7      185         0.487
# 8      235         0.469
# 9      235         0.435
# 10     210          0.48
# 11     245         0.516
# 12     245         0.493
# 13     185         0.374
# 14     185         0.424
# 15     180         0.441
# 16     220         0.503
# 17     194         0.503
# 18     225         0.425
# 19     210         0.371
# 20     240         0.504
# 21     225           0.4
# 22     263         0.482
# 23     210         0.475
# 24     235         0.428
# 25     230         0.559
# 26     190         0.441
# 27     220         0.492
# 28     210         0.402
# 29     180         0.415
# 30     235         0.492
# 31     185         0.484
# 32     175         0.387
# 33     192         0.436
# 34     263         0.482
# 35     180          0.34
# 36     240         0.516
# 37     210         0.475
# 38     160         0.412
# 39     230         0.411
# 40     245         0.407
# 41     228         0.445
# 42     155         0.291
# 43     200         0.449
# 44     235         0.546
# 45     235          0.48
# 46     105         0.359
# 47     180         0.528
# 48     185         0.352
# 49     245         0.414
# 50     180         0.425
# 51     240         0.599
# 52     225         0.482
# 53     215         0.457
# 54     230         0.435

# %%
plt.scatter(x1,y)

# %%
model=LinearRegression()

# %%
model.fit(x1,y)
# Out:
# LinearRegression()

# %%
X1=sm.add_constant(x1)

# %%
model=sm.OLS(y,X1).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           PointsScored   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                 -0.014
# Method:                 Least Squares   F-statistic:                    0.2481
# Date:                Sun, 17 Sep 2023   Prob (F-statistic):              0.621
# Time:                        09:16:08   Log-Likelihood:                -171.83
# No. Observations:                  54   AIC:                             347.7
# Df Residuals:                      52   BIC:                             351.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         17.6256     11.743      1.501      0.139      -5.938      41.189
# Height        -0.8858      1.778     -0.498      0.621      -4.455       2.683
# ==============================================================================
# Omnibus:                        8.995   Durbin-Watson:                   1.793
# Prob(Omnibus):                  0.011   Jarque-Bera (JB):                8.803
# Skew:                           0.977   Prob(JB):                       0.0123
# Kurtosis:                       3.313   Cond. No.                         98.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x2=data.iloc[:,1:2]

# %%
x2
# Out:
#     Weight
# 0      225
# 1      180
# 2      190
# 3      180
# 4      205
# 5      225
# 6      185
# 7      235
# 8      235
# 9      210
# 10     245
# 11     245
# 12     185
# 13     185
# 14     180
# 15     220
# 16     194
# 17     225
# 18     210
# 19     240
# 20     225
# 21     263
# 22     210
# 23     235
# 24     230
# 25     190
# 26     220
# 27     210
# 28     180
# 29     235
# 30     185
# 31     175
# 32     192
# 33     263
# 34     180
# 35     240
# 36     210
# 37     160
# 38     230
# 39     245
# 40     228
# 41     155
# 42     200
# 43     235
# 44     235
# 45     105
# 46     180
# 47     185
# 48     245
# 49     180
# 50     240
# 51     225
# 52     215
# 53     230

# %%
plt.scatter(x2,y)

# %%
model=LinearRegression()
model.fit(x2,y)
# Out:
# LinearRegression()

# %%
X2=sm.add_constant(x2)
model=sm.OLS(y,X2).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           PointsScored   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.019
# Method:                 Least Squares   F-statistic:                  0.005039
# Date:                Sun, 17 Sep 2023   Prob (F-statistic):              0.944
# Time:                        09:16:10   Log-Likelihood:                -171.96
# No. Observations:                  54   AIC:                             347.9
# Df Residuals:                      52   BIC:                             351.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         12.1935      5.731      2.128      0.038       0.693      23.694
# Weight        -0.0019      0.027     -0.071      0.944      -0.056       0.052
# ==============================================================================
# Omnibus:                        7.888   Durbin-Watson:                   1.792
# Prob(Omnibus):                  0.019   Jarque-Bera (JB):                7.461
# Skew:                           0.900   Prob(JB):                       0.0240
# Kurtosis:                       3.278   Cond. No.                     1.50e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.5e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# x3=data.iloc[:,2:3]

# %%
x3=data.iloc[:,2:3]

# %%
x3
# Out:
#     SuccessGoals
# 0          0.442
# 1          0.435
# 2          0.456
# 3          0.416
# 4          0.449
# 5          0.431
# 6          0.487
# 7          0.469
# 8          0.435
# 9          0.480
# 10         0.516
# 11         0.493
# 12         0.374
# 13         0.424
# 14         0.441
# 15         0.503
# 16         0.503
# 17         0.425
# 18         0.371
# 19         0.504
# 20         0.400
# 21         0.482
# 22         0.475
# 23         0.428
# 24         0.559
# 25         0.441
# 26         0.492
# 27         0.402
# 28         0.415
# 29         0.492
# 30         0.484
# 31         0.387
# 32         0.436
# 33         0.482
# 34         0.340
# 35         0.516
# 36         0.475
# 37         0.412
# 38         0.411
# 39         0.407
# 40         0.445
# 41         0.291
# 42         0.449
# 43         0.546
# 44         0.480
# 45         0.359
# 46         0.528
# 47         0.352
# 48         0.414
# 49         0.425
# 50         0.599
# 51         0.482
# 52         0.457
# 53         0.435

# %%
model=LinearRegression()
model.fit(x3,y)
# Out:
# LinearRegression()

# %%
X3=sm.add_constant(x3)
model=sm.OLS(y,X3).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           PointsScored   R-squared:                       0.115
# Model:                            OLS   Adj. R-squared:                  0.098
# Method:                 Least Squares   F-statistic:                     6.741
# Date:                Sun, 17 Sep 2023   Prob (F-statistic):             0.0122
# Time:                        09:16:10   Log-Likelihood:                -168.67
# No. Observations:                  54   AIC:                             341.3
# Df Residuals:                      52   BIC:                             345.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const           -4.0801      6.160     -0.662      0.511     -16.441       8.281
# SuccessGoals    35.3383     13.611      2.596      0.012       8.026      62.650
# ==============================================================================
# Omnibus:                        6.217   Durbin-Watson:                   1.977
# Prob(Omnibus):                  0.045   Jarque-Bera (JB):                5.487
# Skew:                           0.768   Prob(JB):                       0.0643
# Kurtosis:                       3.282   Cond. No.                         21.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x4=data.iloc[:,3:4]

# %%
x4
# Out:
#     SuccessThrows
# 0           0.672
# 1           0.797
# 2           0.761
# 3           0.651
# 4           0.900
# 5           0.780
# 6           0.771
# 7           0.750
# 8           0.818
# 9           0.825
# 10          0.632
# 11          0.757
# 12          0.709
# 13          0.782
# 14          0.775
# 15          0.880
# 16          0.833
# 17          0.571
# 18          0.816
# 19          0.714
# 20          0.765
# 21          0.655
# 22          0.244
# 23          0.728
# 24          0.721
# 25          0.757
# 26          0.747
# 27          0.739
# 28          0.713
# 29          0.742
# 30          0.861
# 31          0.721
# 32          0.785
# 33          0.655
# 34          0.821
# 35          0.728
# 36          0.846
# 37          0.813
# 38          0.595
# 39          0.573
# 40          0.726
# 41          0.707
# 42          0.804
# 43          0.784
# 44          0.744
# 45          0.839
# 46          0.790
# 47          0.701
# 48          0.778
# 49          0.872
# 50          0.713
# 51          0.701
# 52          0.734
# 53          0.764

# %%
model=LinearRegression()
model.fit(x4,y)
# Out:
# LinearRegression()

# %%
X4=sm.add_constant(x4)
model=sm.OLS(y,X4).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           PointsScored   R-squared:                       0.060
# Model:                            OLS   Adj. R-squared:                  0.042
# Method:                 Least Squares   F-statistic:                     3.316
# Date:                Sun, 17 Sep 2023   Prob (F-statistic):             0.0743
# Time:                        09:16:11   Log-Likelihood:                -170.29
# No. Observations:                  54   AIC:                             344.6
# Df Residuals:                      52   BIC:                             348.6
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             1.0907      5.928      0.184      0.855     -10.805      12.986
# SuccessThrows    14.4234      7.920      1.821      0.074      -1.470      30.316
# ==============================================================================
# Omnibus:                        8.396   Durbin-Watson:                   1.935
# Prob(Omnibus):                  0.015   Jarque-Bera (JB):                8.311
# Skew:                           0.958   Prob(JB):                       0.0157
# Kurtosis:                       3.160   Cond. No.                         15.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x_all=data.iloc[:,:-1]

# %%
x_all.head()
# Out:
#    Height  Weight  SuccessGoals  SuccessThrows
# 0     6.8     225         0.442          0.672
# 1     6.3     180         0.435          0.797
# 2     6.4     190         0.456          0.761
# 3     6.2     180         0.416          0.651
# 4     6.9     205         0.449          0.900

# %%
model=LinearRegression()
model.fit(x_all,y)
# Out:
# LinearRegression()

# %%
X_All=sm.add_constant(x_all)
model=sm.OLS(y,X_All).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           PointsScored   R-squared:                       0.222
# Model:                            OLS   Adj. R-squared:                  0.159
# Method:                 Least Squares   F-statistic:                     3.501
# Date:                Sun, 17 Sep 2023   Prob (F-statistic):             0.0136
# Time:                        09:16:12   Log-Likelihood:                -165.17
# No. Observations:                  54   AIC:                             340.3
# Df Residuals:                      49   BIC:                             350.3
# Df Model:                           4
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             4.1487     14.855      0.279      0.781     -25.704      34.001
# Height           -3.6905      2.971     -1.242      0.220      -9.661       2.280
# Weight            0.0095      0.046      0.204      0.839      -0.084       0.102
# SuccessGoals     47.9402     15.709      3.052      0.004      16.372      79.509
# SuccessThrows    11.3710      7.869      1.445      0.155      -4.441      27.183
# ==============================================================================
# Omnibus:                        7.089   Durbin-Watson:                   2.099
# Prob(Omnibus):                  0.029   Jarque-Bera (JB):                6.471
# Skew:                           0.835   Prob(JB):                       0.0393
# Kurtosis:                       3.296   Cond. No.                     4.60e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.6e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
